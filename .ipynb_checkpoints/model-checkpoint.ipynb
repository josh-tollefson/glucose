# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import imblearn
from imblearn.over_sampling import SMOTE 

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_curve, auc, precision_recall_curve

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
seed=42

# %%
infile = './processed/CLARITY_Export_2021-03-01_min30_max60.csv'
df = pd.read_csv(infile)
df.head()
# Out:
#          30        35        40        45        50        55        60  Low
# 0 -0.486657 -0.106526  0.186563  0.398467  0.381482  0.381482  0.381482  0.0
# 1 -0.661791 -0.486657 -0.106526  0.186563  0.398467  0.381482  0.381482  0.0
# 2 -0.994067 -0.661791 -0.486657 -0.106526  0.186563  0.398467  0.381482  0.0
# 3  0.073435 -0.994067 -0.661791 -0.486657 -0.106526  0.186563  0.398467  0.0
# 4 -0.300523  0.073435 -0.994067 -0.661791 -0.486657 -0.106526 -0.106526  0.0

# %%
df['Low'].value_counts()
# Out:
# 0.0    24903
# 1.0     1881
# Name: Low, dtype: int64

# %% [markdown]
# Classes imablanced (17000+ 0 / Not Low vs 1300 1 / Low), so try SMOTE Over and Undersampling

# %%
train, test = train_test_split(df, test_size=0.2, random_state=seed)
train_x = train.iloc[:,0:-1]
test_x = test.iloc[:,0:-1]

train_y = train.iloc[:,-1]
test_y = test.iloc[:,-1]

# %%
sm = SMOTE(random_state=seed)

res_x, res_y = sm.fit_resample(train_x, train_y) ### Resample training set

# %%
model = LogisticRegression().fit(res_x, res_y)

probs = model.predict_proba(test_x)
preds = probs[:,1]

class_names = ['Not Low Glucose', 'Low Glucose']
disp = plot_confusion_matrix(model, 
                             test_x, 
                             test_y,
                             display_labels=class_names,
                             cmap=plt.cm.Blues)

# %%
fpr, tpr, threshold = roc_curve(test_y, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(res_x, res_y)

disp = plot_confusion_matrix(clf, 
                             test_x, 
                             test_y,
                             display_labels=class_names,
                             cmap=plt.cm.Blues)

# %% [markdown]
# Undersample the majority class

# %%
low = df[df['Low'] == 1.0]
not_low = df[df['Low'] == 0.0].sample(n = 1292, random_state=seed)

df_us = low.append(not_low)

# %%
### Train on undersampled set
train, test = train_test_split(df_us, test_size=0.2, random_state=seed)
train_x = train.iloc[:,0:-1]
train_y = train.iloc[:,-1]

test_x = test.iloc[:,0:-1]
test_y = test.iloc[:,-1]

# %%
model = LogisticRegression().fit(train_x, train_y)

probs = model.predict_proba(test_x)
preds = probs[:,1]

class_names = ['Not Low Glucose', 'Low Glucose']
disp = plot_confusion_matrix(model, 
                             test_x, 
                             test_y,
                             display_labels=class_names,
                             cmap=plt.cm.Blues)

# %%
fpr, tpr, threshold = roc_curve(test_y, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# What if we use a longer time interval for extrapolation?

# %%
infile = './processed/CLARITY_Export_2021-03-01_min15_max60.csv'
df = pd.read_csv(infile)
df.dropna(inplace=True)
df.tail()
# Out:
#              15        20        25        30        35        40        45  \
# 26854 -0.510934 -0.510934 -0.510934 -0.510934 -0.510934 -2.840286 -2.840286
# 26855  0.294770  0.294770 -0.045081 -0.300523 -0.300523 -0.300523 -0.300523
# 26856  0.294770  0.294770  0.294770 -0.045081 -0.300523 -0.300523 -0.300523
# 26857  0.294770  0.294770  0.294770  0.294770 -0.045081 -0.300523 -0.300523
# 26858  1.010631  1.010631  0.294770  0.294770  0.294770 -0.045081 -0.300523
#
#              50        55        60  Low
# 26854 -2.840286 -2.840286 -2.840286  0.0
# 26855 -0.300523 -0.300523 -0.300523  0.0
# 26856 -0.300523 -0.300523 -0.300523  0.0
# 26857 -0.300523 -0.300523 -0.300523  0.0
# 26858 -0.300523 -0.300523 -0.300523  0.0

# %%
df.hist(column='30', bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000279F9FB8888>]],
#       dtype=object)

# %%
train, test = train_test_split(df, test_size=0.2, random_state=seed)
train_x = train.iloc[:,0:-1]
test_x = test.iloc[:,0:-1]

train_y = train.iloc[:,-1]
test_y = test.iloc[:,-1]

# %%
sm = SMOTE(random_state=seed)

res_x, res_y = sm.fit_resample(train_x, train_y) ### Resample training set

# %%
model = RandomForestClassifier(min_samples_leaf=20).fit(res_x, res_y)

probs = model.predict_proba(test_x)
preds = probs[:,1]

class_names = ['Not Low Glucose', 'Low Glucose']
disp = plot_confusion_matrix(model, 
                             test_x, 
                             test_y,
                             display_labels=class_names,
                             cmap=plt.cm.Blues)

# %%
model = LogisticRegression().fit(res_x, res_y)

probs = model.predict_proba(test_x)
preds = probs[:,1]

class_names = ['Not Low Glucose', 'Low Glucose']
disp = plot_confusion_matrix(model, 
                             test_x, 
                             test_y,
                             display_labels=class_names,
                             cmap=plt.cm.Blues)

# %% [markdown]
# What causes the high false positive rate?
#
# First guess: maybe duplicated/interpolated values

# %%
def get_pred_rows(test_y, preds, df):
    
    idxs = test_y.iloc[preds > 0.5].index ### positive predictions (i.e., Low predictions)

    return df.iloc[idxs]

# %%
df_positive = get_pred_rows(test_y, preds, df)

# %%
try:
    df_positive.drop(columns='num_uniq', inplace=True)
    df_positive['num_uniq'] = df_positive.apply(pd.Series.nunique, axis=1)
except KeyError:
    df_positive['num_uniq'] = df_positive.apply(pd.Series.nunique, axis=1)

    
df_positive.tail()
df_positive.hist(column='num_uniq', by='Low')
# Out:
# C:\Users\Josh\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000279F87A6808>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000279F87BCD48>],
#       dtype=object)

# %%
from scipy.interpolate import interp1d

ind = 2050
columns = df.columns[0:-1].astype(int)

print(df.iloc[ind, -1])
f = interp1d(columns, df.iloc[ind, 0:-1], kind='slinear', fill_value='extrapolate')
print(df.iloc[ind, 0:-1])
plt.scatter(columns, df.iloc[ind, 0:-1])
plt.plot(np.linspace(60, 0, 30), f(np.linspace(60, 0, 30)))
print(f(0))
# Out:
# 1.0
# 15   -1.309473
# 20   -1.210584
# 25   -1.115475
# 30   -1.084563
# 35   -1.146776
# 40   -1.276071
# 45   -1.594169
# 50   -2.003016
# 55   -2.285021
# 60   -2.093513
# Name: 2050, dtype: float64
# -1.6061394082191613

# %%
infile = './processed/CLARITY_Export_2021-03-01_min20_max60_raw.csv'
df = pd.read_csv(infile)
df.dropna(inplace=True)
df.head()
# Out:
#       20     25     30     35     40     45     50     55     60  Current  Low
# 0  135.0  147.0  146.0  146.0  146.0  146.0  146.0  146.0  146.0     84.0  0.0
# 1  135.0  135.0  147.0  146.0  146.0  146.0  146.0  146.0  146.0    129.0  0.0
# 2  135.0  135.0  147.0  146.0  146.0  146.0  146.0  146.0  146.0    129.0  0.0
# 3  120.0  135.0  147.0  146.0  146.0  146.0  146.0  146.0  146.0    111.0  0.0
# 4   84.0   96.0  103.0  120.0  135.0  147.0  146.0  146.0  146.0     83.0  0.0

# %%
from scipy.interpolate import interp1d

ind = 161
columns = df.columns[0:-2].astype(int)

print(df.iloc[ind, -1])
f = interp1d(columns, df.iloc[ind, 0:-2], kind='slinear', fill_value='extrapolate')
print(df.iloc[ind, 0:-2])
plt.scatter(columns, df.iloc[ind, 0:-2])
plt.plot(np.linspace(60, 0, 30), f(np.linspace(60, 0, 30)))
print(f(0))
# Out:
# 1.0
# 20    74.0
# 25    76.0
# 30    76.0
# 35    78.0
# 40    78.0
# 45    79.0
# 50    81.0
# 55    81.0
# 60    81.0
# Name: 161, dtype: float64
# 66.0

# %%
from scipy.interpolate import interp1d

def interp_glucose(times, values, kind='slinear'):
    
    f = interp1d(times, values, kind=kind, fill_value='extrapolate')
    return f(0)

# %%
preds = []
columns = df.columns[0:-2].astype(int)

for i in range(df.shape[0]):
    pred = interp_glucose(columns, df.iloc[i, 0:-2], kind='slinear')
    if pred <= 70:
        preds.append(1.0)
    else:
        preds.append(0.0)

# %%
matching_1 = np.where( (preds == df["Low"]) & (df["Low"] == 1.0) )
print( 'True Positive Rate: {:.2f}'.format(len(matching_1[0]) / df[df["Low"] == 1.0].shape[0] ))

matching_0 = np.where( (preds == df["Low"]) & (df["Low"] == 0.0) )
print(  'True Negative Rate: {:.2f}'.format(len(matching_0[0]) / df[df["Low"] == 0.0].shape[0] ))

mismatch_fp = np.where( (preds != df["Low"]) & (df["Low"] == 0.0) )
print(  'False Positive Rate: {:.2f}'.format(len(mismatch_fp[0]) / df[df["Low"] == 0.0].shape[0] ))

mismatch_fn = np.where( (preds != df["Low"]) & (df["Low"] == 1.0) )
print(  'False Negative Rate: {:.2f}'.format(len(mismatch_fn[0]) / df[df["Low"] == 1.0].shape[0]) )
# Out:
# True Positive Rate: 0.71
# True Negative Rate: 0.94
# False Positive Rate: 0.06
# False Negative Rate: 0.29

# %%
train, test = train_test_split(df, test_size=0.2, random_state=seed)
train_x = train.iloc[:,0:-2]
test_x = test.iloc[:,0:-2]

train_y = train.iloc[:,-1]
test_y = test.iloc[:,-1]

# %%
sm = SMOTE(random_state=seed)

res_x, res_y = sm.fit_resample(train_x, train_y) ### Resample training set

# %%
model = RandomForestClassifier().fit(res_x, res_y)

probs = model.predict_proba(test_x)
preds = probs[:,1]

class_names = ['Not Low Glucose', 'Low Glucose']
disp = plot_confusion_matrix(model, 
                             test_x, 
                             test_y,
                             display_labels=class_names,
                             cmap=plt.cm.Blues)

# %%
print( 'True Positive Rate: {:.2f}'.format(276 / (86 + 276)) )
print( 'True Negative Rate: {:.2f}'.format(4773 / (4773 + 234)) )
print( 'False Positive Rate: {:.2f}'.format(234 / (234 + 4773)) )
print( 'False Negative Rate: {:.2f}'.format(86 / (86 + 276)) )
# Out:
# True Positive Rate: 0.76
# True Negative Rate: 0.95
# False Positive Rate: 0.05
# False Negative Rate: 0.24

# %%
low = df[df['Low'] == 1.0]
not_low = df[df['Low'] == 0.0].sample(n = low.shape[0], random_state=seed)

df_us = low.append(not_low)

# %%
train, test = train_test_split(df_us, test_size=0.2, random_state=seed)
train_x = train.iloc[:,0:-2]
test_x = test.iloc[:,0:-2]

train_y = train.iloc[:,-1]
test_y = test.iloc[:,-1]

# %%
model = RandomForestClassifier(max_depth=6).fit(train_x, train_y)

probs = model.predict_proba(test_x)
preds = probs[:,1]

class_names = ['Not Low Glucose', 'Low Glucose']
disp = plot_confusion_matrix(model, 
                             test_x, 
                             test_y,
                             display_labels=class_names,
                             cmap=plt.cm.Blues)

# %%
train, test = train_test_split(df, test_size=0.99, random_state=seed)
train_x = train.iloc[:,0:-2]
test_x = test.iloc[:,0:-2]

train_y = train.iloc[:,-1]
test_y = test.iloc[:,-1]

# %%
probs = model.predict_proba(test_x)
preds = probs[:,1]

class_names = ['Not Low Glucose', 'Low Glucose']
disp = plot_confusion_matrix(model, 
                             test_x, 
                             test_y,
                             display_labels=class_names,
                             cmap=plt.cm.Blues)

# %%
preds = model.predict(df.iloc[:,0:-2])

mismatch_fp = np.where( (preds != df["Low"].values) & (df["Low"].values == 0.0) )

fp_rows = df.iloc[mismatch_fp]

fp_rows.hist(column='20', bins=15)
fp_rows.hist(column='Current', bins=15)

mismatch_fn = np.where( (preds != df["Low"].values) & (df["Low"].values == 1.0) )

fn_rows = df.iloc[mismatch_fn]

fn_rows.hist(column='20')
fn_rows.hist(column='Current', bins=15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028C40CE0A88>]],
#       dtype=object)

# %%
estimator = model.estimators_[5]

from sklearn import tree

from sklearn.tree import export_graphviz
# Export as dot file
# export_graphviz(estimator, out_file='tree.dot', 
#                 feature_names = df.columns[:-2],
#                 class_names = ['Not Low', 'Low'],
#                 rounded = True, proportion = False, 
#                 precision = 2, filled = True)

fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=600)

tree.plot_tree(estimator)
fig.savefig('tree.png')

plt.show()

# Convert to png using system command (requires Graphviz)
# import os
# os.system('dot -Tpng tree.dot -o tree.png')# Display in jupyter notebook

# from IPython.display import Image
# Image(filename = 'tree.png')

# %%
train, test = train_test_split(df_us, test_size=0.2, random_state=seed)
train_x = train.iloc[:,0:-2]
test_x = test.iloc[:,0:-2]

train_y = train.iloc[:,-1]
test_y = test.iloc[:,-1]

train, test = train_test_split(df, test_size=0.2, random_state=seed)
test_x = test.iloc[:,0:-2]
test_y = test.iloc[:,-1]


from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report


tuned_parameters = [{'max_depth': [2, 4, 6, 10], 'min_samples_leaf': [1, 5, 10],
                     'max_features': ['auto', 'sqrt', 'log2']}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()
    
    ### Default is 5-fold cross validation

    clf = GridSearchCV(
        RandomForestClassifier(), tuned_parameters, scoring='%s_macro' % score
    )
    clf.fit(train_x, train_y)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = test_y, clf.predict(test_x)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5}
#
# Grid scores on development set:
#
# 0.863 (+/-0.033) for {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1}
# 0.862 (+/-0.030) for {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5}
# 0.861 (+/-0.034) for {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 10}
# 0.863 (+/-0.031) for {'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1}
# 0.859 (+/-0.027) for {'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5}
# 0.864 (+/-0.025) for {'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 10}
# 0.863 (+/-0.027) for {'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1}
# 0.861 (+/-0.026) for {'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5}
# 0.861 (+/-0.031) for {'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 10}
# 0.884 (+/-0.016) for {'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1}
# 0.883 (+/-0.020) for {'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5}
# 0.884 (+/-0.021) for {'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 10}
# 0.882 (+/-0.018) for {'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1}
# 0.881 (+/-0.020) for {'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5}
# 0.882 (+/-0.021) for {'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10}
# 0.880 (+/-0.020) for {'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1}
# 0.881 (+/-0.019) for {'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5}
# 0.882 (+/-0.018) for {'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10}
# 0.885 (+/-0.017) for {'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1}
# 0.885 (+/-0.018) for {'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5}
# 0.887 (+/-0.027) for {'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 10}
# 0.885 (+/-0.014) for {'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1}
# 0.886 (+/-0.018) for {'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5}
# 0.886 (+/-0.023) for {'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 10}
# 0.885 (+/-0.017) for {'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1}
# 0.886 (+/-0.018) for {'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 5}
# 0.884 (+/-0.024) for {'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 10}
# 0.885 (+/-0.018) for {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1}
# 0.884 (+/-0.023) for {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5}
# 0.886 (+/-0.024) for {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 10}
# 0.886 (+/-0.020) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1}
# 0.886 (+/-0.021) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5}
# 0.886 (+/-0.026) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10}
# 0.886 (+/-0.018) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1}
# 0.888 (+/-0.015) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5}
# 0.883 (+/-0.020) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.87      0.92      5005
#          1.0       0.33      0.91      0.48       361
#
#     accuracy                           0.87      5366
#    macro avg       0.66      0.89      0.70      5366
# weighted avg       0.95      0.87      0.90      5366
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1}
#
# Grid scores on development set:
#
# 0.858 (+/-0.034) for {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1}
# 0.859 (+/-0.032) for {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5}
# 0.862 (+/-0.032) for {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 10}
# 0.860 (+/-0.030) for {'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1}
# 0.862 (+/-0.028) for {'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5}
# 0.860 (+/-0.028) for {'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 10}
# 0.859 (+/-0.031) for {'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1}
# 0.860 (+/-0.032) for {'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5}
# 0.860 (+/-0.034) for {'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 10}
# 0.882 (+/-0.022) for {'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1}
# 0.882 (+/-0.019) for {'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5}
# 0.880 (+/-0.019) for {'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 10}
# 0.881 (+/-0.017) for {'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1}
# 0.881 (+/-0.020) for {'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5}
# 0.882 (+/-0.021) for {'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10}
# 0.881 (+/-0.016) for {'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1}
# 0.882 (+/-0.022) for {'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5}
# 0.881 (+/-0.018) for {'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10}
# 0.883 (+/-0.022) for {'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1}
# 0.885 (+/-0.024) for {'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5}
# 0.886 (+/-0.020) for {'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 10}
# 0.885 (+/-0.016) for {'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1}
# 0.886 (+/-0.020) for {'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5}
# 0.885 (+/-0.022) for {'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 10}
# 0.885 (+/-0.015) for {'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1}
# 0.883 (+/-0.023) for {'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 5}
# 0.884 (+/-0.024) for {'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 10}
# 0.886 (+/-0.021) for {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1}
# 0.887 (+/-0.014) for {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5}
# 0.884 (+/-0.018) for {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 10}
# 0.889 (+/-0.021) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1}
# 0.886 (+/-0.016) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5}
# 0.884 (+/-0.025) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10}
# 0.886 (+/-0.017) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1}
# 0.886 (+/-0.019) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5}
# 0.887 (+/-0.026) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.86      0.93      5005
#          1.0       0.34      0.95      0.50       361
#
#     accuracy                           0.87      5366
#    macro avg       0.67      0.91      0.71      5366
# weighted avg       0.95      0.87      0.90      5366

# %%
preds = clf.predict(df.iloc[:,0:-2])

mismatch_fp = np.where( (preds != df["Low"].values) & (df["Low"].values == 0.0) )

fp_rows = df.iloc[mismatch_fp]

fp_rows['Diff'] = fp_rows['Current'] - fp_rows['20']

#fp_rows.hist(column='20', bins=10)
#fp_rows.hist(column='Current', bins=10)
fig, ax = plt.subplots()
plt.scatter(fp_rows['Current'], fp_rows['20'], alpha=0.25)
plt.xlabel('Current')
plt.ylabel('20 min ago')

mismatch_fn = np.where( (preds != df["Low"].values) & (df["Low"].values == 1.0) )

fn_rows = df.iloc[mismatch_fn]

#fn_rows.hist(column='20')
#fn_rows.hist(column='Current', bins=15)
fig, ax = plt.subplots()

plt.scatter(fn_rows['Current'], fn_rows['20'], alpha=0.25)
plt.xlabel('Current')
plt.ylabel('20 min ago')
# Out:
# C:\Users\Josh\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# Text(0, 0.5, '20 min ago')

# %%
#'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1
            
train, test = train_test_split(df_us, test_size=0.2, random_state=seed)
train_x = train.iloc[:,0:-2]
test_x = test.iloc[:,0:-2]

train_y = train.iloc[:,-1]
test_y = test.iloc[:,-1]

train, test = train_test_split(df, test_size=0.2, random_state=seed)
test_x = test.iloc[:,0:-2]
test_y = test.iloc[:,-1]

model = RandomForestClassifier(max_depth=10, max_features='sqrt', min_samples_leaf=1).fit(train_x, train_y)
probs = model.predict_proba(test_x)

preds = clf.predict(df.iloc[:,0:-2])

mismatch_fp = np.where( (preds != df["Low"].values) & (df["Low"].values == 0.0) )

fp_rows = df.iloc[mismatch_fp]

fp_rows['Diff'] = fp_rows['Current'] - fp_rows['20']

#fp_rows.hist(column='20', bins=10)
#fp_rows.hist(column='Current', bins=10)
fig, ax = plt.subplots()
plt.scatter(fp_rows['Current'], fp_rows['20'], alpha=0.25)
plt.xlabel('Current')
plt.ylabel('20 min ago')

mismatch_fn = np.where( (preds != df["Low"].values) & (df["Low"].values == 1.0) )

fn_rows = df.iloc[mismatch_fn]

#fn_rows.hist(column='20')
#fn_rows.hist(column='Current', bins=15)
fig, ax = plt.subplots()

plt.scatter(fn_rows['Current'], fn_rows['20'], alpha=0.25)
plt.xlabel('Current')
plt.ylabel('20 min ago')
# Out:
# C:\Users\Josh\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Text(0, 0.5, '20 min ago')
